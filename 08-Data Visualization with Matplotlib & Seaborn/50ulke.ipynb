# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
sns.set(rc={'figure.figsize':[9, 9]}, font_scale=1.2)

# %%
df = pd.read_csv('50ulke.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     float64
#  5   Continent        50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  National Income     Growth    Per person
# count    50.00000        50.000000  50.000000     50.000000
# mean     24.50000      1646.348200   3.320400  27696.000000
# std      14.57738      3448.554429   2.053468  25094.131496
# min       0.00000       231.570000  -0.740000   1615.000000
# 25%      12.25000       353.440000   1.795000   6402.000000
# 50%      24.50000       522.985000   2.880000  14565.500000
# 75%      36.75000      1504.895000   4.287500  48738.250000
# max      49.00000     20412.870000   7.810000  86835.000000

# %%
sns.distplot(df['National Income'])
# Out:
# /home/vindar/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='National Income', ylabel='Density'>

# %%
sns.distplot(df['Growth'])
# Out:
# /home/vindar/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Growth', ylabel='Density'>

# %%
sns.distplot(df['National Income'], kde=False, bins=30, color='m')
# Out:
# /home/vindar/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='National Income'>

# %%
sns.kdeplot(df['Growth'], shade=True, color= 'g')
# Out:
# <AxesSubplot:xlabel='Growth', ylabel='Density'>

# %%
sns.kdeplot(df['Per person'], shade=True, color= 'g')
# Out:
# <AxesSubplot:xlabel='Per person', ylabel='Density'>

# %%
sns.jointplot(x='Per person', y='National Income', data=df, kind='scatter')

# %%
sns.jointplot(x='Per person', y='Growth', data=df, kind='scatter')

# %%
sns.jointplot(x='Growth', y='Per person', data=df, kind='reg')

# %%
sns.jointplot(y='Per person', x='Growth', data=df, kind='kde', shade=True)

# %%
sns.jointplot(x='Growth', y='National Income', data=df, kind='hex', color='m', height=8)

# %%
sns.pairplot(df, height= 3.5, aspect=1.3)

# %%
sns.pairplot(df, hue='Continent', height=3, aspect=1.3)

# %%
sns.pairplot(df, vars=['National Income', 'Per person'], hue='Continent' ,height=5, aspect=1.3)

# %%
sns.boxplot(y="Per person", x="Continent", data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Per person'>

# %%
sns.boxplot(y="National Income", x="Continent", data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
df
# Out:
#     Unnamed: 0                 Countries  National Income  Growth  Per person  \
# 0            0             United States         20412.87    2.27     62152.0
# 1            1                     China         14092.51    6.86     10088.0
# 2            2                     Japan          5167.05    1.71     40849.0
# 3            3                   Germany          4211.64    2.51     50842.0
# 4            4            United Kingdom          2936.29    1.79     44177.0
# 5            5                    France          2925.10    1.85     44934.0
# 6            6                     India          2848.23    6.74      2135.0
# 7            7                     Italy          2181.97    1.47     35914.0
# 8            8                    Brazil          2138.92    0.98     10224.0
# 9            9                    Canada          1798.51    3.00     48466.0
# 10          10                    Russia          1719.90    1.55     11947.0
# ...

# %%
sns.boxplot(y="Growth", x="Continent", data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.violinplot(y="Growth", x="Continent", data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.stripplot(x="Continent", y="National Income", data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
sns.stripplot(y='Countries', x="Continent", data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Countries'>

# %%
sns.boxplot(y="Growth", x="Continent", data=df)
sns.stripplot(y="Growth", x="Continent", color="#474646", size=5, data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.violinplot(y="Growth", x="Continent", data=df)
sns.stripplot(y="Growth", x="Continent", color="#474646", size=5, data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.stripplot(y='Countries', x="National Income",hue='Continent', data=df)
# Out:
# <AxesSubplot:xlabel='National Income', ylabel='Countries'>

# %%
sns.stripplot(y='Growth', x="Continent", data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.swarmplot(y='National Income', x="Continent", data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
sns.violinplot(y="Growth", x="Continent", data=df)
sns.swarmplot(y="Growth", x="Continent", color="#474646", size=5, data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.countplot(y='Growth', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Growth'>

# %%
sns.countplot(x='Continent', data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='count'>

# %%
df.corr()
# Out:
#                  Unnamed: 0  National Income    Growth  Per person
# Unnamed: 0         1.000000        -0.549732  0.261063   -0.273373
# National Income   -0.549732         1.000000  0.008961    0.159121
# Growth             0.261063         0.008961  1.000000   -0.252786
# Per person        -0.273373         0.159121 -0.252786    1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>
