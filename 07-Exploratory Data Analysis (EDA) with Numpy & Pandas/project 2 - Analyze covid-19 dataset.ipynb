# %%
import pandas as pd

# %%
cov = pd.read_csv("covid-19.csv")

# %%
cov.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
cov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %% [markdown]
# What is the region with the highest deaths?

# %%
cov[cov['Deaths'] == cov['Deaths'].max()]
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %%
cov[cov['Deaths'] == cov['Deaths'].max()]['Country/Region']
# Out:
# 173    US
# Name: Country/Region, dtype: object

# %% [markdown]
# What is the region with the highest deaths?

# %%
cov[cov['Deaths'] == cov['Deaths'].min()]
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered  Active  \
# 19                             Bhutan         99       0         86      13
# 30                           Cambodia        226       0        147      79
# 49                           Dominica         18       0         18       0
# 55                            Eritrea        265       0        191      74
# 59                               Fiji         27       0         18       9
# 68                          Greenland         14       0         13       1
# 69                            Grenada         23       0         23       0
# 75                           Holy See         12       0         12       0
# 94                               Laos         20       0         19       1
# 114                          Mongolia        289       0        222      67
# 130                  Papua New Guinea         62       0         11      51
# ...

# %%
cov[cov['Deaths'] == cov['Deaths'].min()]['Country/Region']
# Out:
# 19                               Bhutan
# 30                             Cambodia
# 49                             Dominica
# 55                              Eritrea
# 59                                 Fiji
# 68                            Greenland
# 69                              Grenada
# 75                             Holy See
# 94                                 Laos
# 114                            Mongolia
# 130                    Papua New Guinea
# 140               Saint Kitts and Nevis
# 141                         Saint Lucia
# 142    Saint Vincent and the Grenadines
# 148                          Seychelles
# 168                         Timor-Leste
# 181                             Vietnam
# Name: Country/Region, dtype: object

# %% [markdown]
# what are the top 5 most country/region of recovered from covid-19

# %%
cov['Country/Region'].value_counts().head(5)
# Out:
# Afghanistan    1
# Pakistan       1
# Nepal          1
# Netherlands    1
# New Zealand    1
# Name: Country/Region, dtype: int64

# %%
cov
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# what are the region that covid-19 increased in one week

# %%
cov[cov['1 week % increase'] == cov['1 week % increase'].max()]['WHO Region']
# Out:
# 130    Western Pacific
# Name: WHO Region, dtype: object

# %% [markdown]
# how many recovered from covid-19 in all Country/Region
