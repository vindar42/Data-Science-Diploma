# %%
import os
f = os.listdir("../../code")
f
# Out:
# ['Project 1 - Thanos',
#  '02-Python Statements',
#  '01-Python Data types',
#  '00-Python Input and Output',
#  '04-Built-in Modules',
#  '03-Functions']

# %%
f= os.listdir("../../code/02-Python Statements")
f
# Out:
# ['test.txt',
#  '01-for Loops.ipynb',
#  '.ipynb_checkpoints',
#  '04-List Comprehensions.ipynb',
#  '02-while Loops.ipynb',
#  'big.py',
#  '00-if, elif, and else Statements.ipynb',
#  'prime.py',
#  '03-Useful-Operators.ipynb',
#  '05-Statements Assessment Test.ipynb']

# %%
my_file = open('../../code/02-Python Statements/05-Statements Assessment Test.ipynb', 'r')
print(my_file.read())
my_file.close()
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {
#     "collapsed": true
#    },
#    "source": [
#     "# Statements Assessment Test\n",
#     "Let's test your knowledge!"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "**Use <code>for</code>, .split(), and <code>if</code> to create a Statement that will print out words that start with 's':**"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 18,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "st = 'Print only the words that start with s in this sentence'"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 19,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "start\n",
#       "s\n",
#       "sentence\n"
#      ]
#     }
#    ],
#    "source": [
#     "#Code here\n",
#     "for i in st.split():\n",
# ...
